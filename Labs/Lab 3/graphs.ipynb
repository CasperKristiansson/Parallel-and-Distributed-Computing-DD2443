# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 1

# %%
threads = [1, 2, 4, 8]

A1_times = [
    [117809209, 83942583, 79183042, 84912125, 80312792],
    [185133792, 170852583, 172176500, 187048791, 169879041],
    [506452875, 557010834, 370508958, 281670541, 609886042],
    [966427833, 1108304417, 896478625, 1193194000, 841973792]
]

A2_times = [
    [110473708, 97317959, 100477292, 110422084, 98905833],
    [239884792, 222304083, 126781625, 120664583, 165233375],
    [348404375, 277525209, 267995208, 275634791, 215197875],
    [251058083, 314114541, 303677625, 400406208, 271248625]
]

A1_avg = [np.mean(times) for times in A1_times]
A2_avg = [np.mean(times) for times in A2_times]

B1_times = [
    [55123084, 61145584, 53128083, 59858750, 89652333],
    [187755042, 175342333, 172732917, 161756167, 167699583],
    [620027500, 564377083, 442386084, 585097166, 642698959],
    [1240521208, 1237348667, 1123240000, 1221400833, 1247150250]
]

B2_times = [
    [122045458, 146805333, 114984584, 122878958, 113403000],
    [244559208, 248751791, 241582542, 227605417, 232107209],
    [372361417, 319765250, 473386375, 422043000, 380208875],
    [753352708, 592947334, 448466083, 437521958, 633465250]
]

B1_avg = [np.mean(times) for times in B1_times]
B2_avg = [np.mean(times) for times in B2_times]

plt.figure(figsize=(10, 6))
plt.plot(threads, A1_avg, marker='o', label='A.1 (1:1:8)')
plt.plot(threads, A2_avg, marker='s', label='A.2 (1:1:0)')
plt.plot(threads, B1_avg, marker='x', label='B.1 (1:1:8)')
plt.plot(threads, B2_avg, marker='d', label='B.2 (1:1:0)')

plt.title("Average Measurement Time vs Threads")
plt.xlabel("Threads")
plt.ylabel("Average Measurement Time")
plt.xticks(threads)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Task 2

# %%
threads = [1, 2, 4, 8]

A1_uniform_times = [
    [70746875, 69711625, 67766541, 89155708, 71922416],  # 1 thread
    [221488000, 206020250, 180972042, 199120500, 214536959],  # 2 threads
    [765376208, 846076875, 769214250, 739866625, 783174583],  # 4 threads
    [1801803916, 1664028417, 2122736666, 1651231500, 1579528250]  # 8 threads
]

A2_uniform_times = [
    [145469250, 134565333, 128052917, 141073417, 126167500],  # 1 thread
    [347891542, 375936000, 307568583, 384325417, 339061250],  # 2 threads
    [931492750, 970434042, 1011588750, 922885917, 1236513000],  # 4 threads
    [2051449458, 2105292708, 2107394250, 2147824958, 2175334458]  # 8 threads
]

B1_normal_times = [
    [82793917, 81395625, 81165792, 89565500, 84556333],  # 1 thread
    [203458584, 190551375, 209232458, 179919458, 202957667],  # 2 threads
    [781342042, 746420208, 783684542, 770664875, 779087833],  # 4 threads
    [1596547791, 1578877041, 1648095833, 1586307542, 1663664750]  # 8 threads
]

B2_normal_times = [
    [135230209, 145817666, 137787792, 144180416, 150643625],  # 1 thread
    [368309500, 334053958, 309025708, 303179542, 298913708],  # 2 threads
    [956335958, 962222583, 946477417, 979106000, 958772583],  # 4 threads
    [2038569208, 2047096416, 2020686958, 2074609417, 2045710208]  # 8 threads
]

B1_uniform_avg = [np.mean(times) for times in A1_uniform_times]
B2_uniform_avg = [np.mean(times) for times in A2_uniform_times]
B1_normal_avg = [np.mean(times) for times in B1_normal_times]
B2_normal_avg = [np.mean(times) for times in B2_normal_times]

plt.figure(figsize=(10, 6))
plt.plot(threads, B1_uniform_avg, marker='o', label='A.1 Uniform (1:1:8)')
plt.plot(threads, B2_uniform_avg, marker='s', label='A.2 Uniform (1:1:0)')
plt.plot(threads, B1_normal_avg, marker='^', label='B.1 Normal (1:1:8)')
plt.plot(threads, B2_normal_avg, marker='d', label='B.2 Normal (1:1:0)')

plt.title("Average Measurement Time vs Threads")
plt.xlabel("Threads")
plt.ylabel("Average Measurement Time")
plt.xticks(threads)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Task 2.4

# %%
threads = [1, 2, 4, 8]

A1_uniform_times_globallog = [
    [81537000, 84666959, 68387500, 68387333, 69947708],
    [252600375, 255641125, 215458000, 240116833, 239473041],
    [775341458, 788150500, 794315458, 743699792, 791719625],
    [1762630041, 1672462000, 1747074792, 1697732333, 1638218042]
]

A2_uniform_times_globallog = [
    [140331625, 145960250, 134498333, 144324875, 139413000],
    [432123166, 412468708, 391195084, 359159666, 370104125],
    [977150458, 941682459, 914699791, 983911458, 965354083],
    [1997087417, 2076068792, 2143530750, 2073941708, 2139820875]
]

B1_normal_times_globallog = [
    [93300125, 93355291, 79417667, 84115708, 80869000],
    [269262583, 208861250, 205584375, 230989167, 224409125],
    [760372334, 777331916, 782582416, 832864667, 749468833],
    [1670994208, 1679258834, 1645573000, 1706421291, 1733366666]
]

B2_normal_times_globallog = [
    [149652916, 127288459, 140809083, 134725625, 133323584],
    [306133292, 337127041, 313906750, 319517833, 273090625],
    [1001436083, 974382833, 988154041, 942387833, 1045928417],
    [2168649417, 2329545166, 2259135333, 2161223542, 2135005917]
]

A1_uniform_avg_globallog = [np.mean(times) for times in A1_uniform_times_globallog]
A2_uniform_avg_globallog = [np.mean(times) for times in A2_uniform_times_globallog]
B1_normal_avg_globallog = [np.mean(times) for times in B1_normal_times_globallog]
B2_normal_avg_globallog = [np.mean(times) for times in B2_normal_times_globallog]

plt.figure(figsize=(10, 6))
plt.plot(threads, A1_uniform_avg_globallog, marker='o', label='A.1 Uniform (1:1:8) GlobalLog')
plt.plot(threads, A2_uniform_avg_globallog, marker='s', label='A.2 Uniform (1:1:0) GlobalLog')
plt.plot(threads, B1_normal_avg_globallog, marker='^', label='B.1 Normal (1:1:8) GlobalLog')
plt.plot(threads, B2_normal_avg_globallog, marker='d', label='B.2 Normal (1:1:0) GlobalLog')

plt.title("Average Measurement Time vs Threads (GlobalLog)")
plt.xlabel("Threads")
plt.ylabel("Average Measurement Time")
plt.xticks(threads)
plt.legend()
plt.grid(True)
plt.show()

# %%
threads = [1, 2, 4, 8]

A1_normal_times_locked = [
    [74833458, 81038375, 89947000, 84077541, 100096917],
    [228352500, 221478458, 211804500, 212790792, 238778375],
    [730971875, 733998959, 768048958, 653520458, 819605375],
    [1600476667, 1620295209, 1586293625, 1474294791, 1551064167]
]

A2_normal_times_locked = [
    [138071625, 208774667, 168773041, 143377958, 144249292],
    [355193458, 361744792, 456989125, 329386500, 311560833],
    [939995417, 954488917, 899565791, 894803000, 992344917],
    [2042826000, 1989754375, 1848003042, 1928381334, 2021386917]
]

B1_uniform_times_locked = [
    [72199625, 72223500, 69859542, 68574875, 67503541],
    [224500209, 202991542, 226334625, 217111542, 303928000],
    [749860250, 706122208, 735880250, 752398250, 748847916],
    [1845694792, 1607945500, 1763872084, 1750633667, 1753590416]
]

B2_uniform_times_locked = [
    [144797667, 134284042, 124319167, 129877500, 158627458],
    [364098834, 347900958, 394274667, 343139459, 301584792],
    [1064149667, 1066949875, 959097083, 934948583, 1064843792],
    [2112748125, 1992025916, 2078837208, 2017218125, 2145478459]
]

A1_normal_avg_locked = [np.mean(times) for times in A1_normal_times_locked]
A2_normal_avg_locked = [np.mean(times) for times in A2_normal_times_locked]
B1_uniform_avg_locked = [np.mean(times) for times in B1_uniform_times_locked]
B2_uniform_avg_locked = [np.mean(times) for times in B2_uniform_times_locked]

plt.figure(figsize=(10, 6))
plt.plot(threads, A1_normal_avg_locked, marker='o', label='A.1 Normal (1:1:8) Locked')
plt.plot(threads, A2_normal_avg_locked, marker='s', label='A.2 Normal (1:1:0) Locked')
plt.plot(threads, B1_uniform_avg_locked, marker='^', label='B.1 Uniform (1:1:8) Locked')
plt.plot(threads, B2_uniform_avg_locked, marker='d', label='B.2 Uniform (1:1:0) Locked')

plt.title("Average Measurement Time vs Threads (Locked)")
plt.xlabel("Threads")
plt.ylabel("Average Measurement Time")
plt.xticks(threads)
plt.legend()
plt.grid(True)
plt.show()
