# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Task 1

# %%
threads = [1, 2, 4, 8]

A1_times = [
    [117809209, 83942583, 79183042, 84912125, 80312792],
    [185133792, 170852583, 172176500, 187048791, 169879041],
    [506452875, 557010834, 370508958, 281670541, 609886042],
    [966427833, 1108304417, 896478625, 1193194000, 841973792]
]

A2_times = [
    [110473708, 97317959, 100477292, 110422084, 98905833],
    [239884792, 222304083, 126781625, 120664583, 165233375],
    [348404375, 277525209, 267995208, 275634791, 215197875],
    [251058083, 314114541, 303677625, 400406208, 271248625]
]

A1_avg = [np.mean(times) for times in A1_times]
A2_avg = [np.mean(times) for times in A2_times]

B1_times = [
    [55123084, 61145584, 53128083, 59858750, 89652333],
    [187755042, 175342333, 172732917, 161756167, 167699583],
    [620027500, 564377083, 442386084, 585097166, 642698959],
    [1240521208, 1237348667, 1123240000, 1221400833, 1247150250]
]

B2_times = [
    [122045458, 146805333, 114984584, 122878958, 113403000],
    [244559208, 248751791, 241582542, 227605417, 232107209],
    [372361417, 319765250, 473386375, 422043000, 380208875],
    [753352708, 592947334, 448466083, 437521958, 633465250]
]

B1_avg = [np.mean(times) for times in B1_times]
B2_avg = [np.mean(times) for times in B2_times]

plt.figure(figsize=(10, 6))
plt.plot(threads, A1_avg, marker='o', label='A.1 (1:1:8)')
plt.plot(threads, A2_avg, marker='s', label='A.2 (1:1:0)')
plt.plot(threads, B1_avg, marker='x', label='B.1 (1:1:8)')
plt.plot(threads, B2_avg, marker='d', label='B.2 (1:1:0)')

plt.title("Average Measurement Time vs Threads")
plt.xlabel("Threads")
plt.ylabel("Average Measurement Time")
plt.xticks(threads)
plt.legend()
plt.grid(True)
plt.show()
